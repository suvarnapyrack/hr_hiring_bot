# %%
n={'resume_items': {'source_type': 'drive', 'jd_text': 'Job Title: Artificial Intelligence (AI) Intern\nLocation: [Remote / Onsite – City, State]\nDepartment: AI & Data Science\nDuration: [e.g., 3 Months / 6 Months]\nStipend: [Yes / No – Mention amount if applicable]\nStart Date: [DD/MM/YYYY]\nApplication Deadline: [DD/MM/YYYY]\n\nAbout the Company:\n[Company Name] is a forward-thinking technology company specializing in AI-driven solutions across industries such as healthcare, finance, retail, and education. Our mission is to solve complex real-world problems through intelligent systems and data-driven innovation. We believe in nurturing young talent and providing them with a platform to learn, grow, and make an impact.\n\nInternship Overview:\nWe are looking for a highly motivated AI Intern to support our Artificial Intelligence and Machine Learning team. This is a hands-on internship where you will work closely with data scientists, machine learning engineers, and software developers to build and deploy intelligent systems. The role is ideal for someone who is passionate about AI and wants to gain practical experience in a professional environment.\n\nRoles and Responsibilities:\nAs an AI Intern, your responsibilities will include:\n\n🔍 Data Handling & Preprocessing\nCollect, clean, and preprocess structured and unstructured datasets\n\nPerform exploratory data analysis (EDA) to understand dataset distributions and patterns\n\nHandle missing data, outliers, and data normalization techniques\n\n🧠 Model Building & Evaluation\nAssist in designing, training, testing, and evaluating machine learning and deep learning models\n\nWork on supervised and unsupervised learning problems\n\nImplement algorithms for classification, regression, clustering, or recommendation systems\n\n🤖 AI Technologies Implementation\nApply models in Natural Language Processing (NLP), Computer Vision, or Time Series Forecasting, based on project needs\n\nExperiment with frameworks like TensorFlow, PyTorch, Hugging Face, OpenAI, etc.\n\n🛠 Tool & Platform Utilization\nWork with Python libraries: NumPy, Pandas, Scikit-learn, Matplotlib, Seaborn\n\nUse platforms such as Jupyter Notebook, Google Colab, VS Code, or Streamlit\n\nOptional: Experience with cloud platforms (AWS, GCP, Azure) or version control (Git, GitHub)\n\n📊 Reporting & Documentation\nDocument code, experiments, findings, and model performance\n\nPresent progress in weekly meetings with the technical team\n\nCollaborate in agile teams using task-tracking tools like Jira or Trello\n\nRequired Qualifications:\nPursuing or recently completed a Bachelor’s or Master’s in Computer Science, Data Science, Engineering, Mathematics, or a related field\n\nSolid understanding of machine learning and AI fundamentals\n\nHands-on experience with Python programming\n\nFamiliarity with ML libraries (Scikit-learn, TensorFlow, or PyTorch)\n\nGood problem-solving skills and a strong analytical mindset\n\nClear communication and eagerness to learn new tools and concepts\n\nPreferred Skills (Bonus):\nExperience with LLMs, GPT-based APIs, or LangChain\n\nFamiliarity with OpenCV or NLP libraries like SpaCy, NLTK, or Transformers\n\nKnowledge of SQL or NoSQL databases\n\nParticipation in Kaggle or GitHub projects\n\n', 'resume': 'resumes/from_drive/resume_1.pdf'}, 'jd_text': 'Job Title: Artificial Intelligence (AI) Intern\nLocation: [Remote / Onsite – City, State]\nDepartment: AI & Data Science\nDuration: [e.g., 3 Months / 6 Months]\nStipend: [Yes / No – Mention amount if applicable]\nStart Date: [DD/MM/YYYY]\nApplication Deadline: [DD/MM/YYYY]\n\nAbout the Company:\n[Company Name] is a forward-thinking technology company specializing in AI-driven solutions across industries such as healthcare, finance, retail, and education. Our mission is to solve complex real-world problems through intelligent systems and data-driven innovation. We believe in nurturing young talent and providing them with a platform to learn, grow, and make an impact.\n\nInternship Overview:\nWe are looking for a highly motivated AI Intern to support our Artificial Intelligence and Machine Learning team. This is a hands-on internship where you will work closely with data scientists, machine learning engineers, and software developers to build and deploy intelligent systems. The role is ideal for someone who is passionate about AI and wants to gain practical experience in a professional environment.\n\nRoles and Responsibilities:\nAs an AI Intern, your responsibilities will include:\n\n🔍 Data Handling & Preprocessing\nCollect, clean, and preprocess structured and unstructured datasets\n\nPerform exploratory data analysis (EDA) to understand dataset distributions and patterns\n\nHandle missing data, outliers, and data normalization techniques\n\n🧠 Model Building & Evaluation\nAssist in designing, training, testing, and evaluating machine learning and deep learning models\n\nWork on supervised and unsupervised learning problems\n\nImplement algorithms for classification, regression, clustering, or recommendation systems\n\n🤖 AI Technologies Implementation\nApply models in Natural Language Processing (NLP), Computer Vision, or Time Series Forecasting, based on project needs\n\nExperiment with frameworks like TensorFlow, PyTorch, Hugging Face, OpenAI, etc.\n\n🛠 Tool & Platform Utilization\nWork with Python libraries: NumPy, Pandas, Scikit-learn, Matplotlib, Seaborn\n\nUse platforms such as Jupyter Notebook, Google Colab, VS Code, or Streamlit\n\nOptional: Experience with cloud platforms (AWS, GCP, Azure) or version control (Git, GitHub)\n\n📊 Reporting & Documentation\nDocument code, experiments, findings, and model performance\n\nPresent progress in weekly meetings with the technical team\n\nCollaborate in agile teams using task-tracking tools like Jira or Trello\n\nRequired Qualifications:\nPursuing or recently completed a Bachelor’s or Master’s in Computer Science, Data Science, Engineering, Mathematics, or a related field\n\nSolid understanding of machine learning and AI fundamentals\n\nHands-on experience with Python programming\n\nFamiliarity with ML libraries (Scikit-learn, TensorFlow, or PyTorch)\n\nGood problem-solving skills and a strong analytical mindset\n\nClear communication and eagerness to learn new tools and concepts\n\nPreferred Skills (Bonus):\nExperience with LLMs, GPT-based APIs, or LangChain\n\nFamiliarity with OpenCV or NLP libraries like SpaCy, NLTK, or Transformers\n\nKnowledge of SQL or NoSQL databases\n\nParticipation in Kaggle or GitHub projects\n\n', 'results': [], 'jd_submitted': True, 'processing_complete': True, 'source_type': 'drive'}

# %%
print(n)
# Out:
# Running cells with 'news_sum_env (Python 3.10.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n news_sum_env ipykernel --update-deps --force-reinstall'
